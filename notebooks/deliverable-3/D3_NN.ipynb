# %% [markdown]
# # Deliverable 3 - Neural Network
#
# - **Preprocessing** (loading dataset, deature selection, standardization, conversion to tensors)
#
#
# - **Model Initialization** (layer architecture, forward pass, activation function, loss, optimizer, kfold, epochs, early stopping)
#
#
# - **Training** (training initialization, loss - accuracy calculation, learning rate adjustment)
#
#
# - **Final Evaluation** (classification report)
#
#
# - **Vizualisation** (loss and accuracy curve)

# %%
''' Classification of mpg of a car depending on the related features using a neural network architecture
Labels: Low, Medium, High 

Parameters: 4 layers 
Hyperparameters: neurons per layer, activation function, lr, epochs

'''
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# # Preprocessing

# %%
#seeds for reproducibility (same results in all machines)
def set_seeds(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
set_seeds(42)

# load dataset
import os
nb_path = os.path.abspath('')
file_path = os.path.join(nb_path, '../../data/df_cleaned.csv')
data = pd.read_csv(file_path)

# features selected based on correlation - our input
features = ['horsepower', 'weight', 'displayments', 'cylinders', 'acceleration']
X = data[features]
y = data['mpg_classes']  # target prediction (3 classes - Low, High, Medium labeled as 0-1-2)

# standardization of features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# converting our input and outputs to tensors so that torch can process them
X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
y_tensor = torch.tensor(y.values, dtype=torch.long)

# %% [markdown]
# # Model Initialization

# %%
# class initialization 4 layers with output layer using Tahn for the activation function
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(5, 64)  # input from 5 features
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
        self.fc4 = nn.Linear(16, 3)  # output has 3 classes
        self.tanh = nn.Tanh() #Tanh activation function

    def forward(self, x):
        x = self.tanh(self.fc1(x))
        x = self.tanh(self.fc2(x))
        x = self.tanh(self.fc3(x))
        x = self.fc4(x)  # no activation on final layer
        return x

# initialization of model, loss, optimizer
model = MLP()
criterion = nn.CrossEntropyLoss() # loss we will use because cross entropy loss is used for classification tasks 
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=1e-4)

# using k-Fold cross validation because our dataset is small
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# training parameters, ReduceLROnPlateau reduces learning rate when test loss stops improving
n_epochs = 60
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, verbose=True, factor=0.1)

# early stopping setup
early_stopping_patience = 7 #if no improvement on 7 consecutive epochs it stops
best_loss = float('inf')
epochs_without_improvement = 0
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/venv/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# # Training

# %%
#keeping track of loss and accuracy scores
train_accuracies = []
test_accuracies = []
train_losses = []
test_losses = []
# for every epoch saves the accuracies, losses and f1 scores 
for epoch in range(n_epochs):
    fold_train_accuracies = []
    fold_test_accuracies = []
    fold_train_losses = []
    fold_test_losses = []
    fold_f1_scores = []
    for train_index, test_index in kf.split(X_scaled, y):
        # spliting sets, e use indeces to keep track of the train and test sets in each of the 5 folds
        X_train, X_test = X_tensor[train_index], X_tensor[test_index]
        y_train, y_test = y_tensor[train_index], y_tensor[test_index]
        #we are wraping the sets into dataset objects and then store them in batches, also we shuffle the data
        train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True)
        test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=32, shuffle=False)
        
        # actual training
        model.train()
        running_loss_train = 0.0
        for inputs, labels in train_loader:
            optimizer.zero_grad() #clears previously accumulated gradients 
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward() #backpropagation to compute gradients through loss backwards
            optimizer.step()# applying gradient descent to update parameters
            running_loss_train += loss.item()
        train_loss = running_loss_train / len(train_loader)
        
        # evaluation of the model - test set
        model.eval()
        y_pred = []
        y_true = []
        running_loss_test = 0.0

        # here no gradient calculations bc we are only evaluating the model
        with torch.no_grad():
            for inputs, labels in test_loader:
                # forward pass
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                # all test losses across the batches 
                running_loss_test += loss.item()
                # computing test accuracy
                _, predicted = torch.max(outputs, 1)
                # storing predictions for evaluation metrics
                y_pred.extend(predicted.cpu().numpy())
                y_true.extend(labels.cpu().numpy())

        #evaluation metrics
        test_loss = running_loss_test / len(test_loader)
        test_accuracy = accuracy_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred, average='macro')

        fold_train_losses.append(train_loss)
        fold_test_losses.append(test_loss)
        fold_test_accuracies.append(test_accuracy)
        fold_f1_scores.append(f1)

    # average across k folds
    mean_train_loss = np.mean(fold_train_losses)
    mean_test_loss = np.mean(fold_test_losses)
    mean_test_accuracy = np.mean(fold_test_accuracies)
    mean_f1 = np.mean(fold_f1_scores)
    # storing results for plotting
    train_losses.append(mean_train_loss)
    test_losses.append(mean_test_loss)
    test_accuracies.append(mean_test_accuracy)

    #epoch summary
    print(f"Epoch {epoch+1}: Train Loss = {mean_train_loss:.4f}, Test Loss = {mean_test_loss:.4f}, Test Acc = {mean_test_accuracy:.4f}, F1-score = {mean_f1:.4f}")

    # learning rate adjustment
    scheduler.step(mean_test_loss)

    # early stoping logic
    if mean_test_loss < best_loss:
        best_loss = mean_test_loss
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1
        print(f"Epochs without improvement: {epochs_without_improvement}/{early_stopping_patience}")

    if epochs_without_improvement >= early_stopping_patience:
        print(f"Early stopping at epoch {epoch+1}")
        break
# Out:
# Epoch 1: Train Loss = 0.6285, Test Loss = 0.5802, Test Acc = 0.7173, F1-score = 0.7001
# Epoch 2: Train Loss = 0.5372, Test Loss = 0.4884, Test Acc = 0.7680, F1-score = 0.7661
# Epoch 3: Train Loss = 0.5310, Test Loss = 0.4982, Test Acc = 0.7547, F1-score = 0.7553
# Epochs without improvement: 1/7
# Epoch 4: Train Loss = 0.5126, Test Loss = 0.4771, Test Acc = 0.7547, F1-score = 0.7532
# Epoch 5: Train Loss = 0.5012, Test Loss = 0.4927, Test Acc = 0.7547, F1-score = 0.7563
# Epochs without improvement: 1/7
# Epoch 6: Train Loss = 0.5050, Test Loss = 0.4432, Test Acc = 0.7867, F1-score = 0.7862
# Epoch 7: Train Loss = 0.4679, Test Loss = 0.4353, Test Acc = 0.7920, F1-score = 0.7927
# Epoch 8: Train Loss = 0.4870, Test Loss = 0.4332, Test Acc = 0.7947, F1-score = 0.7924
# Epoch 9: Train Loss = 0.4438, Test Loss = 0.4092, Test Acc = 0.7973, F1-score = 0.7971
# Epoch 10: Train Loss = 0.4547, Test Loss = 0.4042, Test Acc = 0.8053, F1-score = 0.8048
# Epoch 11: Train Loss = 0.4078, Test Loss = 0.3811, Test Acc = 0.8320, F1-score = 0.8330
# Epoch 12: Train Loss = 0.4195, Test Loss = 0.4066, Test Acc = 0.8133, F1-score = 0.8132
# Epochs without improvement: 1/7
# Epoch 13: Train Loss = 0.3825, Test Loss = 0.3617, Test Acc = 0.8347, F1-score = 0.8359
# Epoch 14: Train Loss = 0.3878, Test Loss = 0.3779, Test Acc = 0.8293, F1-score = 0.8292
# Epochs without improvement: 1/7
# Epoch 15: Train Loss = 0.3760, Test Loss = 0.3556, Test Acc = 0.8400, F1-score = 0.8400
# Epoch 16: Train Loss = 0.3438, Test Loss = 0.3412, Test Acc = 0.8400, F1-score = 0.8388
# Epoch 17: Train Loss = 0.3365, Test Loss = 0.3119, Test Acc = 0.8533, F1-score = 0.8528
# Epoch 18: Train Loss = 0.3457, Test Loss = 0.3249, Test Acc = 0.8587, F1-score = 0.8586
# Epochs without improvement: 1/7
# Epoch 19: Train Loss = 0.3245, Test Loss = 0.3060, Test Acc = 0.8533, F1-score = 0.8522
# Epoch 20: Train Loss = 0.3035, Test Loss = 0.2753, Test Acc = 0.8720, F1-score = 0.8711
# Epoch 21: Train Loss = 0.2901, Test Loss = 0.2835, Test Acc = 0.8800, F1-score = 0.8790
# Epochs without improvement: 1/7
# Epoch 22: Train Loss = 0.3068, Test Loss = 0.2914, Test Acc = 0.8587, F1-score = 0.8583
# Epochs without improvement: 2/7
# Epoch 23: Train Loss = 0.2648, Test Loss = 0.2600, Test Acc = 0.8773, F1-score = 0.8768
# Epoch 24: Train Loss = 0.2944, Test Loss = 0.2731, Test Acc = 0.8720, F1-score = 0.8701
# Epochs without improvement: 1/7
# Epoch 25: Train Loss = 0.2891, Test Loss = 0.2770, Test Acc = 0.8720, F1-score = 0.8704
# Epochs without improvement: 2/7
# Epoch 26: Train Loss = 0.2595, Test Loss = 0.2722, Test Acc = 0.8773, F1-score = 0.8763
# Epochs without improvement: 3/7
# Epoch 27: Train Loss = 0.2775, Test Loss = 0.2958, Test Acc = 0.8667, F1-score = 0.8651
# Epochs without improvement: 4/7
# Epoch 28: Train Loss = 0.2229, Test Loss = 0.2439, Test Acc = 0.8933, F1-score = 0.8920
# Epoch 29: Train Loss = 0.2056, Test Loss = 0.2579, Test Acc = 0.8987, F1-score = 0.8973
# Epochs without improvement: 1/7
# Epoch 30: Train Loss = 0.2037, Test Loss = 0.2090, Test Acc = 0.9147, F1-score = 0.9135
# Epoch 31: Train Loss = 0.2176, Test Loss = 0.2257, Test Acc = 0.8880, F1-score = 0.8874
# Epochs without improvement: 1/7
# Epoch 32: Train Loss = 0.2204, Test Loss = 0.2186, Test Acc = 0.8960, F1-score = 0.8942
# Epochs without improvement: 2/7
# Epoch 33: Train Loss = 0.1975, Test Loss = 0.2221, Test Acc = 0.9013, F1-score = 0.8999
# Epochs without improvement: 3/7
# Epoch 34: Train Loss = 0.2119, Test Loss = 0.1942, Test Acc = 0.9173, F1-score = 0.9173
# Epoch 35: Train Loss = 0.1931, Test Loss = 0.2099, Test Acc = 0.9013, F1-score = 0.9008
# Epochs without improvement: 1/7
# Epoch 36: Train Loss = 0.1929, Test Loss = 0.1751, Test Acc = 0.9253, F1-score = 0.9252
# Epoch 37: Train Loss = 0.2049, Test Loss = 0.1860, Test Acc = 0.9093, F1-score = 0.9089
# Epochs without improvement: 1/7
# Epoch 38: Train Loss = 0.1674, Test Loss = 0.1777, Test Acc = 0.9200, F1-score = 0.9197
# Epochs without improvement: 2/7
# Epoch 39: Train Loss = 0.1606, Test Loss = 0.1604, Test Acc = 0.9280, F1-score = 0.9272
# Epoch 40: Train Loss = 0.1252, Test Loss = 0.1216, Test Acc = 0.9413, F1-score = 0.9407
# Epoch 41: Train Loss = 0.1838, Test Loss = 0.1821, Test Acc = 0.9227, F1-score = 0.9225
# Epochs without improvement: 1/7
# Epoch 42: Train Loss = 0.2196, Test Loss = 0.1846, Test Acc = 0.9360, F1-score = 0.9354
# Epochs without improvement: 2/7
# Epoch 43: Train Loss = 0.1255, Test Loss = 0.1306, Test Acc = 0.9333, F1-score = 0.9328
# Epochs without improvement: 3/7
# Epoch 44: Train Loss = 0.1524, Test Loss = 0.1553, Test Acc = 0.9387, F1-score = 0.9379
# Epochs without improvement: 4/7
# Epoch 45: Train Loss = 0.1455, Test Loss = 0.1388, Test Acc = 0.9493, F1-score = 0.9488
# Epochs without improvement: 5/7
# Epoch 46: Train Loss = 0.1109, Test Loss = 0.1452, Test Acc = 0.9360, F1-score = 0.9357
# Epochs without improvement: 6/7
# Epoch 47: Train Loss = 0.0941, Test Loss = 0.0945, Test Acc = 0.9707, F1-score = 0.9705
# Epoch 48: Train Loss = 0.0721, Test Loss = 0.0704, Test Acc = 0.9813, F1-score = 0.9812
# Epoch 49: Train Loss = 0.0674, Test Loss = 0.0682, Test Acc = 0.9813, F1-score = 0.9812
# Epoch 50: Train Loss = 0.0643, Test Loss = 0.0665, Test Acc = 0.9813, F1-score = 0.9812
# Epoch 51: Train Loss = 0.0658, Test Loss = 0.0645, Test Acc = 0.9840, F1-score = 0.9840
# Epoch 52: Train Loss = 0.0641, Test Loss = 0.0651, Test Acc = 0.9813, F1-score = 0.9812
# Epochs without improvement: 1/7
# Epoch 53: Train Loss = 0.0603, Test Loss = 0.0634, Test Acc = 0.9840, F1-score = 0.9840
# Epoch 54: Train Loss = 0.0627, Test Loss = 0.0611, Test Acc = 0.9867, F1-score = 0.9867
# Epoch 55: Train Loss = 0.0603, Test Loss = 0.0611, Test Acc = 0.9840, F1-score = 0.9841
# Epoch 56: Train Loss = 0.0607, Test Loss = 0.0611, Test Acc = 0.9840, F1-score = 0.9841
# Epochs without improvement: 1/7
# Epoch 57: Train Loss = 0.0589, Test Loss = 0.0587, Test Acc = 0.9813, F1-score = 0.9814
# Epoch 58: Train Loss = 0.0568, Test Loss = 0.0588, Test Acc = 0.9840, F1-score = 0.9841
# Epochs without improvement: 1/7
# Epoch 59: Train Loss = 0.0573, Test Loss = 0.0574, Test Acc = 0.9840, F1-score = 0.9841
# Epoch 60: Train Loss = 0.0565, Test Loss = 0.0568, Test Acc = 0.9840, F1-score = 0.9841

# %% [markdown]
# # Final Evaluation

# %%
# evaluate on the entire dataset
model.eval()
y_pred = []
y_true = []

with torch.no_grad():
    for inputs, labels in DataLoader(TensorDataset(X_tensor, y_tensor), batch_size=32, shuffle=False):
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        y_pred.extend(predicted.cpu().numpy())
        y_true.extend(labels.cpu().numpy())

#classification report
print("\nFinal Model Evaluation:")
print(classification_report(y_true, y_pred, target_names=['Low', 'Medium', 'High']))
# Out:
# Final Model Evaluation:
#               precision    recall  f1-score   support
#
#          Low       0.98      0.98      0.98       129
#       Medium       0.97      0.98      0.97       127
#         High       0.99      0.98      0.99       119
#
#     accuracy                           0.98       375
#    macro avg       0.98      0.98      0.98       375
# weighted avg       0.98      0.98      0.98       375

# %% [markdown]
# # Vizualization

# %%
# visualizing 
plt.figure(figsize=(12, 5))
# accuracy
plt.subplot(1, 2, 1)
plt.plot(range(1, len(test_accuracies) + 1), test_accuracies, label='Testing accuracy')
plt.title('Accuracy over epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
# loss
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training loss')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Testing loss')
plt.title('Loss over epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()
